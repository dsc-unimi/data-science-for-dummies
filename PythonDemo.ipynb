# %% [markdown]
# # Play with Pokémon
# ## Importiamo le librerie necessarie per svolgere questa demo

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')

# %% [markdown]
# ## Leggiamo il nostro dataset dal file csv

# %%
pokemon=pd.read_csv("dataset/pokemon.csv")

# %% [markdown]
# ## Osserviamo i nostri pokémon

# %%
pokemon
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 6                             ['Torrent', 'Rain Dish']         1.00
# 7                             ['Torrent', 'Rain Dish']         1.00
# 8                             ['Torrent', 'Rain Dish']         1.00
# 9                          ['Shield Dust', 'Run Away']         1.00
# 10                                       ['Shed Skin']         1.00
# 11                     ['Compoundeyes', 'Tinted Lens']         0.50
# 12                         ['Shield Dust', 'Run Away']         0.50
# 13                                       ['Shed Skin']         0.50
# 14                                 ['Swarm', 'Sniper']         0.50
# 15           ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# 16           ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# 17           ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# 18   ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...         1.00
# 19   ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...         1.00
# 20                              ['Keen Eye', 'Sniper']         0.50
# 21                              ['Keen Eye', 'Sniper']         0.50
# 22              ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# 23              ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# 24                          ['Static', 'Lightningrod']         1.00
# 25          ['Static', 'Lightningrod', 'Surge Surfer']         1.00
# 26   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...         1.00
# 27   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...         1.00
# 28               ['Poison Point', 'Rivalry', 'Hustle']         0.50
# 29               ['Poison Point', 'Rivalry', 'Hustle']         0.50
# ..                                                 ...          ...
# 771                                   ['Battle Armor']         1.00
# 772                                     ['RKS System']         1.00
# 773                                   ['Shields Down']         0.50
# 774                                       ['Comatose']         1.00
# 775                                    ['Shell Armor']         0.50
# 776           ['Iron Barbs', 'Lightningrod', 'Sturdy']         0.50
# 777                                       ['Disguise']         0.25
# 778         ['Dazzling', 'Strong Jaw', 'Wonder Skin ']         2.00
# 779            ['Berserk', 'Sap Sipper', 'Cloud Nine']         1.00
# 780                                    ['Steelworker']         1.00
# 781          ['Bulletproof', 'Soundproof', 'Overcoat']         1.00
# 782          ['Bulletproof', 'Soundproof', 'Overcoat']         0.50
# 783          ['Bulletproof', 'Soundproof', 'Overcoat']         0.50
# 784                    ['Electric Surge', 'Telepathy']         0.50
# 785                     ['Psychic Surge', 'Telepathy']         1.00
# 786                      ['Grassy Surge', 'Telepathy']         1.00
# 787                       ['Misty Surge', 'Telepathy']         0.50
# 788                                        ['Unaware']         2.00
# 789                                         ['Sturdy']         2.00
# 790                                ['Full Metal Body']         1.00
# 791                                  ['Shadow Shield']         1.00
# 792                                    ['Beast Boost']         0.50
# 793                                    ['Beast Boost']         0.50
# 794                                    ['Beast Boost']         0.50
# 795                                    ['Beast Boost']         1.00
# 796                                    ['Beast Boost']         0.25
# 797                                    ['Beast Boost']         1.00
# 798                                    ['Beast Boost']         2.00
# 799                                    ['Prism Armor']         2.00
# 800                                     ['Soul-Heart']         0.25
#
#      against_dark  against_dragon  against_electric  against_fairy  \
# 0             1.0             1.0               0.5            0.5
# 1             1.0             1.0               0.5            0.5
# 2             1.0             1.0               0.5            0.5
# 3             1.0             1.0               1.0            0.5
# 4             1.0             1.0               1.0            0.5
# 5             1.0             1.0               2.0            0.5
# 6             1.0             1.0               2.0            1.0
# 7             1.0             1.0               2.0            1.0
# 8             1.0             1.0               2.0            1.0
# 9             1.0             1.0               1.0            1.0
# 10            1.0             1.0               1.0            1.0
# 11            1.0             1.0               2.0            1.0
# 12            1.0             1.0               1.0            0.5
# 13            1.0             1.0               1.0            0.5
# 14            1.0             1.0               1.0            0.5
# 15            1.0             1.0               2.0            1.0
# 16            1.0             1.0               2.0            1.0
# 17            1.0             1.0               2.0            1.0
# 18            1.0             1.0               1.0            1.0
# 19            1.0             1.0               1.0            1.0
# 20            1.0             1.0               2.0            1.0
# 21            1.0             1.0               2.0            1.0
# 22            1.0             1.0               1.0            0.5
# 23            1.0             1.0               1.0            0.5
# 24            1.0             1.0               0.5            1.0
# 25            1.0             1.0               0.5            1.0
# 26            1.0             1.0               0.0            1.0
# 27            1.0             1.0               0.0            1.0
# 28            1.0             1.0               1.0            0.5
# 29            1.0             1.0               1.0            0.5
# ..            ...             ...               ...            ...
# 771           1.0             1.0               1.0            1.0
# 772           1.0             1.0               1.0            1.0
# 773           1.0             1.0               2.0            1.0
# 774           1.0             1.0               1.0            1.0
# 775           1.0             2.0               0.5            1.0
# 776           1.0             0.5               0.5            0.5
# 777           1.0             0.0               1.0            1.0
# 778           2.0             1.0               2.0            1.0
# 779           1.0             2.0               0.5            2.0
# 780           2.0             1.0               0.5            1.0
# 781           1.0             2.0               0.5            2.0
# 782           0.5             2.0               0.5            4.0
# 783           0.5             2.0               0.5            4.0
# 784           0.5             0.0               0.5            1.0
# 785           1.0             0.0               1.0            1.0
# 786           0.5             0.0               0.5            1.0
# 787           0.5             0.0               2.0            1.0
# 788           2.0             1.0               1.0            1.0
# 789           2.0             1.0               1.0            1.0
# 790           2.0             0.5               1.0            0.5
# 791           4.0             1.0               1.0            1.0
# 792           1.0             1.0               1.0            0.5
# 793           0.5             1.0               1.0            2.0
# 794           0.5             1.0               1.0            2.0
# 795           1.0             1.0               0.5            1.0
# 796           1.0             0.5               2.0            0.5
# 797           1.0             0.5               0.5            0.5
# 798           0.5             2.0               0.5            4.0
# 799           2.0             1.0               1.0            1.0
# 800           0.5             0.0               1.0            0.5
#
#      against_fight  against_fire  against_flying  against_ghost  ...  \
# 0             0.50          2.00            2.00            1.0  ...
# 1             0.50          2.00            2.00            1.0  ...
# 2             0.50          2.00            2.00            1.0  ...
# 3             1.00          0.50            1.00            1.0  ...
# 4             1.00          0.50            1.00            1.0  ...
# 5             0.50          0.50            1.00            1.0  ...
# 6             1.00          0.50            1.00            1.0  ...
# 7             1.00          0.50            1.00            1.0  ...
# 8             1.00          0.50            1.00            1.0  ...
# 9             0.50          2.00            2.00            1.0  ...
# 10            0.50          2.00            2.00            1.0  ...
# 11            0.25          2.00            2.00            1.0  ...
# 12            0.25          2.00            2.00            1.0  ...
# 13            0.25          2.00            2.00            1.0  ...
# 14            0.25          2.00            2.00            1.0  ...
# 15            1.00          1.00            1.00            0.0  ...
# 16            1.00          1.00            1.00            0.0  ...
# 17            1.00          1.00            1.00            0.0  ...
# 18            2.00          1.00            1.00            0.0  ...
# 19            2.00          1.00            1.00            0.0  ...
# 20            1.00          1.00            1.00            0.0  ...
# 21            1.00          1.00            1.00            0.0  ...
# 22            0.50          1.00            1.00            1.0  ...
# 23            0.50          1.00            1.00            1.0  ...
# 24            1.00          1.00            0.50            1.0  ...
# 25            1.00          1.00            0.50            1.0  ...
# 26            1.00          1.00            1.00            1.0  ...
# 27            1.00          1.00            1.00            1.0  ...
# 28            0.50          1.00            1.00            1.0  ...
# 29            0.50          1.00            1.00            1.0  ...
# ..             ...           ...             ...            ...  ...
# 771           2.00          1.00            1.00            0.0  ...
# 772           2.00          1.00            1.00            0.0  ...
# 773           1.00          0.50            0.50            1.0  ...
# 774           2.00          1.00            1.00            0.0  ...
# 775           1.00          0.25            1.00            1.0  ...
# 776           2.00          2.00            0.25            1.0  ...
# 777           0.00          1.00            1.00            2.0  ...
# 778           0.50          0.50            1.00            2.0  ...
# 779           2.00          0.50            1.00            0.0  ...
# 780           0.00          2.00            2.00            2.0  ...
# 781           1.00          0.50            1.00            1.0  ...
# 782           1.00          0.50            2.00            1.0  ...
# 783           1.00          0.50            2.00            1.0  ...
# 784           0.50          1.00            0.50            1.0  ...
# 785           0.25          1.00            1.00            2.0  ...
# 786           0.50          2.00            2.00            1.0  ...
# 787           0.50          0.50            1.00            1.0  ...
# 788           0.50          1.00            1.00            2.0  ...
# 789           0.50          1.00            1.00            2.0  ...
# 790           1.00          2.00            0.50            2.0  ...
# 791           0.00          1.00            1.00            4.0  ...
# 792           1.00          0.50            0.50            1.0  ...
# 793           0.50          2.00            4.00            1.0  ...
# 794           0.50          2.00            4.00            1.0  ...
# 795           1.00          1.00            0.50            1.0  ...
# 796           1.00          2.00            0.50            1.0  ...
# 797           2.00          4.00            1.00            1.0  ...
# 798           2.00          0.50            1.00            0.5  ...
# 799           0.50          1.00            1.00            2.0  ...
# 800           1.00          2.00            0.50            1.0  ...
#
#      percentage_male  pokedex_number  sp_attack  sp_defense  speed     type1  \
# 0               88.1               1         65          65     45     grass
# 1               88.1               2         80          80     60     grass
# 2               88.1               3        122         120     80     grass
# 3               88.1               4         60          50     65      fire
# 4               88.1               5         80          65     80      fire
# 5               88.1               6        159         115    100      fire
# 6               88.1               7         50          64     43     water
# 7               88.1               8         65          80     58     water
# 8               88.1               9        135         115     78     water
# 9               50.0              10         20          20     45       bug
# 10              50.0              11         25          25     30       bug
# 11              50.0              12         90          80     70       bug
# 12              50.0              13         20          20     50       bug
# 13              50.0              14         25          25     35       bug
# 14              50.0              15         15          80    145       bug
# 15              50.0              16         35          35     56    normal
# 16              50.0              17         50          50     71    normal
# 17              50.0              18        135          80    121    normal
# 18              50.0              19         25          35     72    normal
# 19              50.0              20         40          80     77    normal
# 20              50.0              21         31          31     70    normal
# 21              50.0              22         61          61    100    normal
# 22              50.0              23         40          54     55    poison
# 23              50.0              24         65          79     80    poison
# 24              50.0              25         50          50     90  electric
# 25              50.0              26         95          85    110  electric
# 26              50.0              27         10          35     40    ground
# 27              50.0              28         25          65     65    ground
# 28               0.0              29         40          40     41    poison
# 29               0.0              30         55          55     56    poison
# ..               ...             ...        ...         ...    ...       ...
# 771              NaN             772         95          95     59    normal
# 772              NaN             773         95          95     95    normal
# 773              NaN             774        100          60    120      rock
# 774             50.0             775         75          95     65    normal
# 775             50.0             776         91          85     36      fire
# 776             50.0             777         40          73     96  electric
# 777             50.0             778         50         105     96     ghost
# 778             50.0             779         70          70     92     water
# 779             50.0             780        135          91     36    normal
# 780              NaN             781         86          90     40     ghost
# 781             50.0             782         45          45     45    dragon
# 782             50.0             783         65          70     65    dragon
# 783             50.0             784        100         105     85    dragon
# 784              NaN             785         95          75    130  electric
# 785              NaN             786        130         115     95   psychic
# 786              NaN             787         85          95     75     grass
# 787              NaN             788         95         130     85     water
# 788              NaN             789         29          31     37   psychic
# 789              NaN             790         29         131     37   psychic
# 790              NaN             791        113          89     97   psychic
# 791              NaN             792        137         107     97   psychic
# 792              NaN             793        127         131    103      rock
# 793              NaN             794         53          53     79       bug
# 794              NaN             795        137          37    151       bug
# 795              NaN             796        173          71     83  electric
# 796              NaN             797        107         101     61     steel
# 797              NaN             798         59          31    109     grass
# 798              NaN             799         97          53     43      dark
# 799              NaN             800        127          89     79   psychic
# 800              NaN             801        130         115     65     steel
#
#         type2  weight_kg  generation  is_legendary
# 0      poison        6.9           1             0
# 1      poison       13.0           1             0
# 2      poison      100.0           1             0
# 3         NaN        8.5           1             0
# 4         NaN       19.0           1             0
# 5      flying       90.5           1             0
# 6         NaN        9.0           1             0
# 7         NaN       22.5           1             0
# 8         NaN       85.5           1             0
# 9         NaN        2.9           1             0
# 10        NaN        9.9           1             0
# 11     flying       32.0           1             0
# 12     poison        3.2           1             0
# 13     poison       10.0           1             0
# 14     poison       29.5           1             0
# 15     flying        1.8           1             0
# 16     flying       30.0           1             0
# 17     flying       39.5           1             0
# 18       dark        NaN           1             0
# 19       dark        NaN           1             0
# 20     flying        2.0           1             0
# 21     flying       38.0           1             0
# 22        NaN        6.9           1             0
# 23        NaN       65.0           1             0
# 24        NaN        6.0           1             0
# 25   electric        NaN           1             0
# 26        ice        NaN           1             0
# 27        ice        NaN           1             0
# 28        NaN        7.0           1             0
# 29        NaN       20.0           1             0
# ..        ...        ...         ...           ...
# 771       NaN      120.5           7             0
# 772       NaN      100.5           7             0
# 773    flying       40.0           7             0
# 774       NaN       19.9           7             0
# 775    dragon      212.0           7             0
# 776     steel        3.3           7             0
# 777     fairy        0.7           7             0
# 778   psychic       19.0           7             0
# 779    dragon      185.0           7             0
# 780     grass      210.0           7             0
# 781       NaN       29.7           7             0
# 782  fighting       47.0           7             0
# 783  fighting       78.2           7             0
# 784     fairy       20.5           7             1
# 785     fairy       18.6           7             1
# 786     fairy       45.5           7             1
# 787     fairy       21.2           7             1
# 788       NaN        0.1           7             1
# 789       NaN      999.9           7             1
# 790     steel      230.0           7             1
# 791     ghost      120.0           7             1
# 792    poison       55.5           7             1
# 793  fighting      333.6           7             1
# 794  fighting       25.0           7             1
# 795       NaN      100.0           7             1
# 796    flying      999.9           7             1
# 797     steel        0.1           7             1
# 798    dragon      888.0           7             1
# 799       NaN      230.0           7             1
# 800     fairy       80.5           7             1
#
# [801 rows x 41 columns]

# %%
pokemon.head(5)['name']
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: name, dtype: object

# %%
pokemon.tail(3)['name']
# Out:
# 798    Guzzlord
# 799    Necrozma
# 800    Magearna
# Name: name, dtype: object

# %%
pokemon.head(1)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# 0             2.0            1.0  ...             88.1               1
#
#    sp_attack  sp_defense  speed  type1   type2  weight_kg  generation  \
# 0         65          65     45  grass  poison        6.9           1
#
#    is_legendary
# 0             0
#
# [1 rows x 41 columns]

# %%
mons=pokemon.set_index('name')
mons
# Out:
#                                                     abilities  against_bug  \
# name
# Bulbasaur                         ['Overgrow', 'Chlorophyll']         1.00
# Ivysaur                           ['Overgrow', 'Chlorophyll']         1.00
# Venusaur                          ['Overgrow', 'Chlorophyll']         1.00
# Charmander                           ['Blaze', 'Solar Power']         0.50
# Charmeleon                           ['Blaze', 'Solar Power']         0.50
# Charizard                            ['Blaze', 'Solar Power']         0.25
# Squirtle                             ['Torrent', 'Rain Dish']         1.00
# Wartortle                            ['Torrent', 'Rain Dish']         1.00
# Blastoise                            ['Torrent', 'Rain Dish']         1.00
# Caterpie                          ['Shield Dust', 'Run Away']         1.00
# Metapod                                         ['Shed Skin']         1.00
# Butterfree                    ['Compoundeyes', 'Tinted Lens']         0.50
# Weedle                            ['Shield Dust', 'Run Away']         0.50
# Kakuna                                          ['Shed Skin']         0.50
# Beedrill                                  ['Swarm', 'Sniper']         0.50
# Pidgey              ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# Pidgeotto           ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# Pidgeot             ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# Rattata     ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...         1.00
# Raticate    ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...         1.00
# Spearow                                ['Keen Eye', 'Sniper']         0.50
# Fearow                                 ['Keen Eye', 'Sniper']         0.50
# Ekans                  ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# Arbok                  ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# Pikachu                            ['Static', 'Lightningrod']         1.00
# Raichu             ['Static', 'Lightningrod', 'Surge Surfer']         1.00
# Sandshrew   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...         1.00
# Sandslash   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...         1.00
# Nidoran♀                ['Poison Point', 'Rivalry', 'Hustle']         0.50
# Nidorina                ['Poison Point', 'Rivalry', 'Hustle']         0.50
# ...                                                       ...          ...
# Type: Null                                   ['Battle Armor']         1.00
# Silvally                                       ['RKS System']         1.00
# Minior                                       ['Shields Down']         0.50
# Komala                                           ['Comatose']         1.00
# Turtonator                                    ['Shell Armor']         0.50
# Togedemaru           ['Iron Barbs', 'Lightningrod', 'Sturdy']         0.50
# Mimikyu                                          ['Disguise']         0.25
# Bruxish            ['Dazzling', 'Strong Jaw', 'Wonder Skin ']         2.00
# Drampa                ['Berserk', 'Sap Sipper', 'Cloud Nine']         1.00
# Dhelmise                                      ['Steelworker']         1.00
# Jangmo-o            ['Bulletproof', 'Soundproof', 'Overcoat']         1.00
# Hakamo-o            ['Bulletproof', 'Soundproof', 'Overcoat']         0.50
# Kommo-o             ['Bulletproof', 'Soundproof', 'Overcoat']         0.50
# Tapu Koko                     ['Electric Surge', 'Telepathy']         0.50
# Tapu Lele                      ['Psychic Surge', 'Telepathy']         1.00
# Tapu Bulu                       ['Grassy Surge', 'Telepathy']         1.00
# Tapu Fini                        ['Misty Surge', 'Telepathy']         0.50
# Cosmog                                            ['Unaware']         2.00
# Cosmoem                                            ['Sturdy']         2.00
# Solgaleo                                  ['Full Metal Body']         1.00
# Lunala                                      ['Shadow Shield']         1.00
# Nihilego                                      ['Beast Boost']         0.50
# Buzzwole                                      ['Beast Boost']         0.50
# Pheromosa                                     ['Beast Boost']         0.50
# Xurkitree                                     ['Beast Boost']         1.00
# Celesteela                                    ['Beast Boost']         0.25
# Kartana                                       ['Beast Boost']         1.00
# Guzzlord                                      ['Beast Boost']         2.00
# Necrozma                                      ['Prism Armor']         2.00
# Magearna                                       ['Soul-Heart']         0.25
#
#             against_dark  against_dragon  against_electric  against_fairy  \
# name
# Bulbasaur            1.0             1.0               0.5            0.5
# Ivysaur              1.0             1.0               0.5            0.5
# Venusaur             1.0             1.0               0.5            0.5
# Charmander           1.0             1.0               1.0            0.5
# Charmeleon           1.0             1.0               1.0            0.5
# Charizard            1.0             1.0               2.0            0.5
# Squirtle             1.0             1.0               2.0            1.0
# Wartortle            1.0             1.0               2.0            1.0
# Blastoise            1.0             1.0               2.0            1.0
# Caterpie             1.0             1.0               1.0            1.0
# Metapod              1.0             1.0               1.0            1.0
# Butterfree           1.0             1.0               2.0            1.0
# Weedle               1.0             1.0               1.0            0.5
# Kakuna               1.0             1.0               1.0            0.5
# Beedrill             1.0             1.0               1.0            0.5
# Pidgey               1.0             1.0               2.0            1.0
# Pidgeotto            1.0             1.0               2.0            1.0
# Pidgeot              1.0             1.0               2.0            1.0
# Rattata              1.0             1.0               1.0            1.0
# Raticate             1.0             1.0               1.0            1.0
# Spearow              1.0             1.0               2.0            1.0
# Fearow               1.0             1.0               2.0            1.0
# Ekans                1.0             1.0               1.0            0.5
# Arbok                1.0             1.0               1.0            0.5
# Pikachu              1.0             1.0               0.5            1.0
# Raichu               1.0             1.0               0.5            1.0
# Sandshrew            1.0             1.0               0.0            1.0
# Sandslash            1.0             1.0               0.0            1.0
# Nidoran♀             1.0             1.0               1.0            0.5
# Nidorina             1.0             1.0               1.0            0.5
# ...                  ...             ...               ...            ...
# Type: Null           1.0             1.0               1.0            1.0
# Silvally             1.0             1.0               1.0            1.0
# Minior               1.0             1.0               2.0            1.0
# Komala               1.0             1.0               1.0            1.0
# Turtonator           1.0             2.0               0.5            1.0
# Togedemaru           1.0             0.5               0.5            0.5
# Mimikyu              1.0             0.0               1.0            1.0
# Bruxish              2.0             1.0               2.0            1.0
# Drampa               1.0             2.0               0.5            2.0
# Dhelmise             2.0             1.0               0.5            1.0
# Jangmo-o             1.0             2.0               0.5            2.0
# Hakamo-o             0.5             2.0               0.5            4.0
# Kommo-o              0.5             2.0               0.5            4.0
# Tapu Koko            0.5             0.0               0.5            1.0
# Tapu Lele            1.0             0.0               1.0            1.0
# Tapu Bulu            0.5             0.0               0.5            1.0
# Tapu Fini            0.5             0.0               2.0            1.0
# Cosmog               2.0             1.0               1.0            1.0
# Cosmoem              2.0             1.0               1.0            1.0
# Solgaleo             2.0             0.5               1.0            0.5
# Lunala               4.0             1.0               1.0            1.0
# Nihilego             1.0             1.0               1.0            0.5
# Buzzwole             0.5             1.0               1.0            2.0
# Pheromosa            0.5             1.0               1.0            2.0
# Xurkitree            1.0             1.0               0.5            1.0
# Celesteela           1.0             0.5               2.0            0.5
# Kartana              1.0             0.5               0.5            0.5
# Guzzlord             0.5             2.0               0.5            4.0
# Necrozma             2.0             1.0               1.0            1.0
# Magearna             0.5             0.0               1.0            0.5
#
#             against_fight  against_fire  against_flying  against_ghost  ...  \
# name                                                                    ...
# Bulbasaur            0.50          2.00            2.00            1.0  ...
# Ivysaur              0.50          2.00            2.00            1.0  ...
# Venusaur             0.50          2.00            2.00            1.0  ...
# Charmander           1.00          0.50            1.00            1.0  ...
# Charmeleon           1.00          0.50            1.00            1.0  ...
# Charizard            0.50          0.50            1.00            1.0  ...
# Squirtle             1.00          0.50            1.00            1.0  ...
# Wartortle            1.00          0.50            1.00            1.0  ...
# Blastoise            1.00          0.50            1.00            1.0  ...
# Caterpie             0.50          2.00            2.00            1.0  ...
# Metapod              0.50          2.00            2.00            1.0  ...
# Butterfree           0.25          2.00            2.00            1.0  ...
# Weedle               0.25          2.00            2.00            1.0  ...
# Kakuna               0.25          2.00            2.00            1.0  ...
# Beedrill             0.25          2.00            2.00            1.0  ...
# Pidgey               1.00          1.00            1.00            0.0  ...
# Pidgeotto            1.00          1.00            1.00            0.0  ...
# Pidgeot              1.00          1.00            1.00            0.0  ...
# Rattata              2.00          1.00            1.00            0.0  ...
# Raticate             2.00          1.00            1.00            0.0  ...
# Spearow              1.00          1.00            1.00            0.0  ...
# Fearow               1.00          1.00            1.00            0.0  ...
# Ekans                0.50          1.00            1.00            1.0  ...
# Arbok                0.50          1.00            1.00            1.0  ...
# Pikachu              1.00          1.00            0.50            1.0  ...
# Raichu               1.00          1.00            0.50            1.0  ...
# Sandshrew            1.00          1.00            1.00            1.0  ...
# Sandslash            1.00          1.00            1.00            1.0  ...
# Nidoran♀             0.50          1.00            1.00            1.0  ...
# Nidorina             0.50          1.00            1.00            1.0  ...
# ...                   ...           ...             ...            ...  ...
# Type: Null           2.00          1.00            1.00            0.0  ...
# Silvally             2.00          1.00            1.00            0.0  ...
# Minior               1.00          0.50            0.50            1.0  ...
# Komala               2.00          1.00            1.00            0.0  ...
# Turtonator           1.00          0.25            1.00            1.0  ...
# Togedemaru           2.00          2.00            0.25            1.0  ...
# Mimikyu              0.00          1.00            1.00            2.0  ...
# Bruxish              0.50          0.50            1.00            2.0  ...
# Drampa               2.00          0.50            1.00            0.0  ...
# Dhelmise             0.00          2.00            2.00            2.0  ...
# Jangmo-o             1.00          0.50            1.00            1.0  ...
# Hakamo-o             1.00          0.50            2.00            1.0  ...
# Kommo-o              1.00          0.50            2.00            1.0  ...
# Tapu Koko            0.50          1.00            0.50            1.0  ...
# Tapu Lele            0.25          1.00            1.00            2.0  ...
# Tapu Bulu            0.50          2.00            2.00            1.0  ...
# Tapu Fini            0.50          0.50            1.00            1.0  ...
# Cosmog               0.50          1.00            1.00            2.0  ...
# Cosmoem              0.50          1.00            1.00            2.0  ...
# Solgaleo             1.00          2.00            0.50            2.0  ...
# Lunala               0.00          1.00            1.00            4.0  ...
# Nihilego             1.00          0.50            0.50            1.0  ...
# Buzzwole             0.50          2.00            4.00            1.0  ...
# Pheromosa            0.50          2.00            4.00            1.0  ...
# Xurkitree            1.00          1.00            0.50            1.0  ...
# Celesteela           1.00          2.00            0.50            1.0  ...
# Kartana              2.00          4.00            1.00            1.0  ...
# Guzzlord             2.00          0.50            1.00            0.5  ...
# Necrozma             0.50          1.00            1.00            2.0  ...
# Magearna             1.00          2.00            0.50            1.0  ...
#
#             percentage_male  pokedex_number  sp_attack  sp_defense  speed  \
# name
# Bulbasaur              88.1               1         65          65     45
# Ivysaur                88.1               2         80          80     60
# Venusaur               88.1               3        122         120     80
# Charmander             88.1               4         60          50     65
# Charmeleon             88.1               5         80          65     80
# Charizard              88.1               6        159         115    100
# Squirtle               88.1               7         50          64     43
# Wartortle              88.1               8         65          80     58
# Blastoise              88.1               9        135         115     78
# Caterpie               50.0              10         20          20     45
# Metapod                50.0              11         25          25     30
# Butterfree             50.0              12         90          80     70
# Weedle                 50.0              13         20          20     50
# Kakuna                 50.0              14         25          25     35
# Beedrill               50.0              15         15          80    145
# Pidgey                 50.0              16         35          35     56
# Pidgeotto              50.0              17         50          50     71
# Pidgeot                50.0              18        135          80    121
# Rattata                50.0              19         25          35     72
# Raticate               50.0              20         40          80     77
# Spearow                50.0              21         31          31     70
# Fearow                 50.0              22         61          61    100
# Ekans                  50.0              23         40          54     55
# Arbok                  50.0              24         65          79     80
# Pikachu                50.0              25         50          50     90
# Raichu                 50.0              26         95          85    110
# Sandshrew              50.0              27         10          35     40
# Sandslash              50.0              28         25          65     65
# Nidoran♀                0.0              29         40          40     41
# Nidorina                0.0              30         55          55     56
# ...                     ...             ...        ...         ...    ...
# Type: Null              NaN             772         95          95     59
# Silvally                NaN             773         95          95     95
# Minior                  NaN             774        100          60    120
# Komala                 50.0             775         75          95     65
# Turtonator             50.0             776         91          85     36
# Togedemaru             50.0             777         40          73     96
# Mimikyu                50.0             778         50         105     96
# Bruxish                50.0             779         70          70     92
# Drampa                 50.0             780        135          91     36
# Dhelmise                NaN             781         86          90     40
# Jangmo-o               50.0             782         45          45     45
# Hakamo-o               50.0             783         65          70     65
# Kommo-o                50.0             784        100         105     85
# Tapu Koko               NaN             785         95          75    130
# Tapu Lele               NaN             786        130         115     95
# Tapu Bulu               NaN             787         85          95     75
# Tapu Fini               NaN             788         95         130     85
# Cosmog                  NaN             789         29          31     37
# Cosmoem                 NaN             790         29         131     37
# Solgaleo                NaN             791        113          89     97
# Lunala                  NaN             792        137         107     97
# Nihilego                NaN             793        127         131    103
# Buzzwole                NaN             794         53          53     79
# Pheromosa               NaN             795        137          37    151
# Xurkitree               NaN             796        173          71     83
# Celesteela              NaN             797        107         101     61
# Kartana                 NaN             798         59          31    109
# Guzzlord                NaN             799         97          53     43
# Necrozma                NaN             800        127          89     79
# Magearna                NaN             801        130         115     65
#
#                type1     type2  weight_kg  generation  is_legendary
# name
# Bulbasaur      grass    poison        6.9           1             0
# Ivysaur        grass    poison       13.0           1             0
# Venusaur       grass    poison      100.0           1             0
# Charmander      fire       NaN        8.5           1             0
# Charmeleon      fire       NaN       19.0           1             0
# Charizard       fire    flying       90.5           1             0
# Squirtle       water       NaN        9.0           1             0
# Wartortle      water       NaN       22.5           1             0
# Blastoise      water       NaN       85.5           1             0
# Caterpie         bug       NaN        2.9           1             0
# Metapod          bug       NaN        9.9           1             0
# Butterfree       bug    flying       32.0           1             0
# Weedle           bug    poison        3.2           1             0
# Kakuna           bug    poison       10.0           1             0
# Beedrill         bug    poison       29.5           1             0
# Pidgey        normal    flying        1.8           1             0
# Pidgeotto     normal    flying       30.0           1             0
# Pidgeot       normal    flying       39.5           1             0
# Rattata       normal      dark        NaN           1             0
# Raticate      normal      dark        NaN           1             0
# Spearow       normal    flying        2.0           1             0
# Fearow        normal    flying       38.0           1             0
# Ekans         poison       NaN        6.9           1             0
# Arbok         poison       NaN       65.0           1             0
# Pikachu     electric       NaN        6.0           1             0
# Raichu      electric  electric        NaN           1             0
# Sandshrew     ground       ice        NaN           1             0
# Sandslash     ground       ice        NaN           1             0
# Nidoran♀      poison       NaN        7.0           1             0
# Nidorina      poison       NaN       20.0           1             0
# ...              ...       ...        ...         ...           ...
# Type: Null    normal       NaN      120.5           7             0
# Silvally      normal       NaN      100.5           7             0
# Minior          rock    flying       40.0           7             0
# Komala        normal       NaN       19.9           7             0
# Turtonator      fire    dragon      212.0           7             0
# Togedemaru  electric     steel        3.3           7             0
# Mimikyu        ghost     fairy        0.7           7             0
# Bruxish        water   psychic       19.0           7             0
# Drampa        normal    dragon      185.0           7             0
# Dhelmise       ghost     grass      210.0           7             0
# Jangmo-o      dragon       NaN       29.7           7             0
# Hakamo-o      dragon  fighting       47.0           7             0
# Kommo-o       dragon  fighting       78.2           7             0
# Tapu Koko   electric     fairy       20.5           7             1
# Tapu Lele    psychic     fairy       18.6           7             1
# Tapu Bulu      grass     fairy       45.5           7             1
# Tapu Fini      water     fairy       21.2           7             1
# Cosmog       psychic       NaN        0.1           7             1
# Cosmoem      psychic       NaN      999.9           7             1
# Solgaleo     psychic     steel      230.0           7             1
# Lunala       psychic     ghost      120.0           7             1
# Nihilego        rock    poison       55.5           7             1
# Buzzwole         bug  fighting      333.6           7             1
# Pheromosa        bug  fighting       25.0           7             1
# Xurkitree   electric       NaN      100.0           7             1
# Celesteela     steel    flying      999.9           7             1
# Kartana        grass     steel        0.1           7             1
# Guzzlord        dark    dragon      888.0           7             1
# Necrozma     psychic       NaN      230.0           7             1
# Magearna       steel     fairy       80.5           7             1
#
# [801 rows x 40 columns]

# %%
pokemon.set_index('name',inplace = True )
pokemon
# Out:
#                                                     abilities  against_bug  \
# name
# Bulbasaur                         ['Overgrow', 'Chlorophyll']         1.00
# Ivysaur                           ['Overgrow', 'Chlorophyll']         1.00
# Venusaur                          ['Overgrow', 'Chlorophyll']         1.00
# Charmander                           ['Blaze', 'Solar Power']         0.50
# Charmeleon                           ['Blaze', 'Solar Power']         0.50
# Charizard                            ['Blaze', 'Solar Power']         0.25
# Squirtle                             ['Torrent', 'Rain Dish']         1.00
# Wartortle                            ['Torrent', 'Rain Dish']         1.00
# Blastoise                            ['Torrent', 'Rain Dish']         1.00
# Caterpie                          ['Shield Dust', 'Run Away']         1.00
# Metapod                                         ['Shed Skin']         1.00
# Butterfree                    ['Compoundeyes', 'Tinted Lens']         0.50
# Weedle                            ['Shield Dust', 'Run Away']         0.50
# Kakuna                                          ['Shed Skin']         0.50
# Beedrill                                  ['Swarm', 'Sniper']         0.50
# Pidgey              ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# Pidgeotto           ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# Pidgeot             ['Keen Eye', 'Tangled Feet', 'Big Pecks']         0.50
# Rattata     ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...         1.00
# Raticate    ['Run Away', 'Guts', 'Hustle', 'Gluttony', 'Hu...         1.00
# Spearow                                ['Keen Eye', 'Sniper']         0.50
# Fearow                                 ['Keen Eye', 'Sniper']         0.50
# Ekans                  ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# Arbok                  ['Intimidate', 'Shed Skin', 'Unnerve']         0.50
# Pikachu                            ['Static', 'Lightningrod']         1.00
# Raichu             ['Static', 'Lightningrod', 'Surge Surfer']         1.00
# Sandshrew   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...         1.00
# Sandslash   ['Sand Veil', 'Sand Rush', 'Snow Cloak', 'Slus...         1.00
# Nidoran♀                ['Poison Point', 'Rivalry', 'Hustle']         0.50
# Nidorina                ['Poison Point', 'Rivalry', 'Hustle']         0.50
# ...                                                       ...          ...
# Type: Null                                   ['Battle Armor']         1.00
# Silvally                                       ['RKS System']         1.00
# Minior                                       ['Shields Down']         0.50
# Komala                                           ['Comatose']         1.00
# Turtonator                                    ['Shell Armor']         0.50
# Togedemaru           ['Iron Barbs', 'Lightningrod', 'Sturdy']         0.50
# Mimikyu                                          ['Disguise']         0.25
# Bruxish            ['Dazzling', 'Strong Jaw', 'Wonder Skin ']         2.00
# Drampa                ['Berserk', 'Sap Sipper', 'Cloud Nine']         1.00
# Dhelmise                                      ['Steelworker']         1.00
# Jangmo-o            ['Bulletproof', 'Soundproof', 'Overcoat']         1.00
# Hakamo-o            ['Bulletproof', 'Soundproof', 'Overcoat']         0.50
# Kommo-o             ['Bulletproof', 'Soundproof', 'Overcoat']         0.50
# Tapu Koko                     ['Electric Surge', 'Telepathy']         0.50
# Tapu Lele                      ['Psychic Surge', 'Telepathy']         1.00
# Tapu Bulu                       ['Grassy Surge', 'Telepathy']         1.00
# Tapu Fini                        ['Misty Surge', 'Telepathy']         0.50
# Cosmog                                            ['Unaware']         2.00
# Cosmoem                                            ['Sturdy']         2.00
# Solgaleo                                  ['Full Metal Body']         1.00
# Lunala                                      ['Shadow Shield']         1.00
# Nihilego                                      ['Beast Boost']         0.50
# Buzzwole                                      ['Beast Boost']         0.50
# Pheromosa                                     ['Beast Boost']         0.50
# Xurkitree                                     ['Beast Boost']         1.00
# Celesteela                                    ['Beast Boost']         0.25
# Kartana                                       ['Beast Boost']         1.00
# Guzzlord                                      ['Beast Boost']         2.00
# Necrozma                                      ['Prism Armor']         2.00
# Magearna                                       ['Soul-Heart']         0.25
#
#             against_dark  against_dragon  against_electric  against_fairy  \
# name
# Bulbasaur            1.0             1.0               0.5            0.5
# Ivysaur              1.0             1.0               0.5            0.5
# Venusaur             1.0             1.0               0.5            0.5
# Charmander           1.0             1.0               1.0            0.5
# Charmeleon           1.0             1.0               1.0            0.5
# Charizard            1.0             1.0               2.0            0.5
# Squirtle             1.0             1.0               2.0            1.0
# Wartortle            1.0             1.0               2.0            1.0
# Blastoise            1.0             1.0               2.0            1.0
# Caterpie             1.0             1.0               1.0            1.0
# Metapod              1.0             1.0               1.0            1.0
# Butterfree           1.0             1.0               2.0            1.0
# Weedle               1.0             1.0               1.0            0.5
# Kakuna               1.0             1.0               1.0            0.5
# Beedrill             1.0             1.0               1.0            0.5
# Pidgey               1.0             1.0               2.0            1.0
# Pidgeotto            1.0             1.0               2.0            1.0
# Pidgeot              1.0             1.0               2.0            1.0
# Rattata              1.0             1.0               1.0            1.0
# Raticate             1.0             1.0               1.0            1.0
# Spearow              1.0             1.0               2.0            1.0
# Fearow               1.0             1.0               2.0            1.0
# Ekans                1.0             1.0               1.0            0.5
# Arbok                1.0             1.0               1.0            0.5
# Pikachu              1.0             1.0               0.5            1.0
# Raichu               1.0             1.0               0.5            1.0
# Sandshrew            1.0             1.0               0.0            1.0
# Sandslash            1.0             1.0               0.0            1.0
# Nidoran♀             1.0             1.0               1.0            0.5
# Nidorina             1.0             1.0               1.0            0.5
# ...                  ...             ...               ...            ...
# Type: Null           1.0             1.0               1.0            1.0
# Silvally             1.0             1.0               1.0            1.0
# Minior               1.0             1.0               2.0            1.0
# Komala               1.0             1.0               1.0            1.0
# Turtonator           1.0             2.0               0.5            1.0
# Togedemaru           1.0             0.5               0.5            0.5
# Mimikyu              1.0             0.0               1.0            1.0
# Bruxish              2.0             1.0               2.0            1.0
# Drampa               1.0             2.0               0.5            2.0
# Dhelmise             2.0             1.0               0.5            1.0
# Jangmo-o             1.0             2.0               0.5            2.0
# Hakamo-o             0.5             2.0               0.5            4.0
# Kommo-o              0.5             2.0               0.5            4.0
# Tapu Koko            0.5             0.0               0.5            1.0
# Tapu Lele            1.0             0.0               1.0            1.0
# Tapu Bulu            0.5             0.0               0.5            1.0
# Tapu Fini            0.5             0.0               2.0            1.0
# Cosmog               2.0             1.0               1.0            1.0
# Cosmoem              2.0             1.0               1.0            1.0
# Solgaleo             2.0             0.5               1.0            0.5
# Lunala               4.0             1.0               1.0            1.0
# Nihilego             1.0             1.0               1.0            0.5
# Buzzwole             0.5             1.0               1.0            2.0
# Pheromosa            0.5             1.0               1.0            2.0
# Xurkitree            1.0             1.0               0.5            1.0
# Celesteela           1.0             0.5               2.0            0.5
# Kartana              1.0             0.5               0.5            0.5
# Guzzlord             0.5             2.0               0.5            4.0
# Necrozma             2.0             1.0               1.0            1.0
# Magearna             0.5             0.0               1.0            0.5
#
#             against_fight  against_fire  against_flying  against_ghost  ...  \
# name                                                                    ...
# Bulbasaur            0.50          2.00            2.00            1.0  ...
# Ivysaur              0.50          2.00            2.00            1.0  ...
# Venusaur             0.50          2.00            2.00            1.0  ...
# Charmander           1.00          0.50            1.00            1.0  ...
# Charmeleon           1.00          0.50            1.00            1.0  ...
# Charizard            0.50          0.50            1.00            1.0  ...
# Squirtle             1.00          0.50            1.00            1.0  ...
# Wartortle            1.00          0.50            1.00            1.0  ...
# Blastoise            1.00          0.50            1.00            1.0  ...
# Caterpie             0.50          2.00            2.00            1.0  ...
# Metapod              0.50          2.00            2.00            1.0  ...
# Butterfree           0.25          2.00            2.00            1.0  ...
# Weedle               0.25          2.00            2.00            1.0  ...
# Kakuna               0.25          2.00            2.00            1.0  ...
# Beedrill             0.25          2.00            2.00            1.0  ...
# Pidgey               1.00          1.00            1.00            0.0  ...
# Pidgeotto            1.00          1.00            1.00            0.0  ...
# Pidgeot              1.00          1.00            1.00            0.0  ...
# Rattata              2.00          1.00            1.00            0.0  ...
# Raticate             2.00          1.00            1.00            0.0  ...
# Spearow              1.00          1.00            1.00            0.0  ...
# Fearow               1.00          1.00            1.00            0.0  ...
# Ekans                0.50          1.00            1.00            1.0  ...
# Arbok                0.50          1.00            1.00            1.0  ...
# Pikachu              1.00          1.00            0.50            1.0  ...
# Raichu               1.00          1.00            0.50            1.0  ...
# Sandshrew            1.00          1.00            1.00            1.0  ...
# Sandslash            1.00          1.00            1.00            1.0  ...
# Nidoran♀             0.50          1.00            1.00            1.0  ...
# Nidorina             0.50          1.00            1.00            1.0  ...
# ...                   ...           ...             ...            ...  ...
# Type: Null           2.00          1.00            1.00            0.0  ...
# Silvally             2.00          1.00            1.00            0.0  ...
# Minior               1.00          0.50            0.50            1.0  ...
# Komala               2.00          1.00            1.00            0.0  ...
# Turtonator           1.00          0.25            1.00            1.0  ...
# Togedemaru           2.00          2.00            0.25            1.0  ...
# Mimikyu              0.00          1.00            1.00            2.0  ...
# Bruxish              0.50          0.50            1.00            2.0  ...
# Drampa               2.00          0.50            1.00            0.0  ...
# Dhelmise             0.00          2.00            2.00            2.0  ...
# Jangmo-o             1.00          0.50            1.00            1.0  ...
# Hakamo-o             1.00          0.50            2.00            1.0  ...
# Kommo-o              1.00          0.50            2.00            1.0  ...
# Tapu Koko            0.50          1.00            0.50            1.0  ...
# Tapu Lele            0.25          1.00            1.00            2.0  ...
# Tapu Bulu            0.50          2.00            2.00            1.0  ...
# Tapu Fini            0.50          0.50            1.00            1.0  ...
# Cosmog               0.50          1.00            1.00            2.0  ...
# Cosmoem              0.50          1.00            1.00            2.0  ...
# Solgaleo             1.00          2.00            0.50            2.0  ...
# Lunala               0.00          1.00            1.00            4.0  ...
# Nihilego             1.00          0.50            0.50            1.0  ...
# Buzzwole             0.50          2.00            4.00            1.0  ...
# Pheromosa            0.50          2.00            4.00            1.0  ...
# Xurkitree            1.00          1.00            0.50            1.0  ...
# Celesteela           1.00          2.00            0.50            1.0  ...
# Kartana              2.00          4.00            1.00            1.0  ...
# Guzzlord             2.00          0.50            1.00            0.5  ...
# Necrozma             0.50          1.00            1.00            2.0  ...
# Magearna             1.00          2.00            0.50            1.0  ...
#
#             percentage_male  pokedex_number  sp_attack  sp_defense  speed  \
# name
# Bulbasaur              88.1               1         65          65     45
# Ivysaur                88.1               2         80          80     60
# Venusaur               88.1               3        122         120     80
# Charmander             88.1               4         60          50     65
# Charmeleon             88.1               5         80          65     80
# Charizard              88.1               6        159         115    100
# Squirtle               88.1               7         50          64     43
# Wartortle              88.1               8         65          80     58
# Blastoise              88.1               9        135         115     78
# Caterpie               50.0              10         20          20     45
# Metapod                50.0              11         25          25     30
# Butterfree             50.0              12         90          80     70
# Weedle                 50.0              13         20          20     50
# Kakuna                 50.0              14         25          25     35
# Beedrill               50.0              15         15          80    145
# Pidgey                 50.0              16         35          35     56
# Pidgeotto              50.0              17         50          50     71
# Pidgeot                50.0              18        135          80    121
# Rattata                50.0              19         25          35     72
# Raticate               50.0              20         40          80     77
# Spearow                50.0              21         31          31     70
# Fearow                 50.0              22         61          61    100
# Ekans                  50.0              23         40          54     55
# Arbok                  50.0              24         65          79     80
# Pikachu                50.0              25         50          50     90
# Raichu                 50.0              26         95          85    110
# Sandshrew              50.0              27         10          35     40
# Sandslash              50.0              28         25          65     65
# Nidoran♀                0.0              29         40          40     41
# Nidorina                0.0              30         55          55     56
# ...                     ...             ...        ...         ...    ...
# Type: Null              NaN             772         95          95     59
# Silvally                NaN             773         95          95     95
# Minior                  NaN             774        100          60    120
# Komala                 50.0             775         75          95     65
# Turtonator             50.0             776         91          85     36
# Togedemaru             50.0             777         40          73     96
# Mimikyu                50.0             778         50         105     96
# Bruxish                50.0             779         70          70     92
# Drampa                 50.0             780        135          91     36
# Dhelmise                NaN             781         86          90     40
# Jangmo-o               50.0             782         45          45     45
# Hakamo-o               50.0             783         65          70     65
# Kommo-o                50.0             784        100         105     85
# Tapu Koko               NaN             785         95          75    130
# Tapu Lele               NaN             786        130         115     95
# Tapu Bulu               NaN             787         85          95     75
# Tapu Fini               NaN             788         95         130     85
# Cosmog                  NaN             789         29          31     37
# Cosmoem                 NaN             790         29         131     37
# Solgaleo                NaN             791        113          89     97
# Lunala                  NaN             792        137         107     97
# Nihilego                NaN             793        127         131    103
# Buzzwole                NaN             794         53          53     79
# Pheromosa               NaN             795        137          37    151
# Xurkitree               NaN             796        173          71     83
# Celesteela              NaN             797        107         101     61
# Kartana                 NaN             798         59          31    109
# Guzzlord                NaN             799         97          53     43
# Necrozma                NaN             800        127          89     79
# Magearna                NaN             801        130         115     65
#
#                type1     type2  weight_kg  generation  is_legendary
# name
# Bulbasaur      grass    poison        6.9           1             0
# Ivysaur        grass    poison       13.0           1             0
# Venusaur       grass    poison      100.0           1             0
# Charmander      fire       NaN        8.5           1             0
# Charmeleon      fire       NaN       19.0           1             0
# Charizard       fire    flying       90.5           1             0
# Squirtle       water       NaN        9.0           1             0
# Wartortle      water       NaN       22.5           1             0
# Blastoise      water       NaN       85.5           1             0
# Caterpie         bug       NaN        2.9           1             0
# Metapod          bug       NaN        9.9           1             0
# Butterfree       bug    flying       32.0           1             0
# Weedle           bug    poison        3.2           1             0
# Kakuna           bug    poison       10.0           1             0
# Beedrill         bug    poison       29.5           1             0
# Pidgey        normal    flying        1.8           1             0
# Pidgeotto     normal    flying       30.0           1             0
# Pidgeot       normal    flying       39.5           1             0
# Rattata       normal      dark        NaN           1             0
# Raticate      normal      dark        NaN           1             0
# Spearow       normal    flying        2.0           1             0
# Fearow        normal    flying       38.0           1             0
# Ekans         poison       NaN        6.9           1             0
# Arbok         poison       NaN       65.0           1             0
# Pikachu     electric       NaN        6.0           1             0
# Raichu      electric  electric        NaN           1             0
# Sandshrew     ground       ice        NaN           1             0
# Sandslash     ground       ice        NaN           1             0
# Nidoran♀      poison       NaN        7.0           1             0
# Nidorina      poison       NaN       20.0           1             0
# ...              ...       ...        ...         ...           ...
# Type: Null    normal       NaN      120.5           7             0
# Silvally      normal       NaN      100.5           7             0
# Minior          rock    flying       40.0           7             0
# Komala        normal       NaN       19.9           7             0
# Turtonator      fire    dragon      212.0           7             0
# Togedemaru  electric     steel        3.3           7             0
# Mimikyu        ghost     fairy        0.7           7             0
# Bruxish        water   psychic       19.0           7             0
# Drampa        normal    dragon      185.0           7             0
# Dhelmise       ghost     grass      210.0           7             0
# Jangmo-o      dragon       NaN       29.7           7             0
# Hakamo-o      dragon  fighting       47.0           7             0
# Kommo-o       dragon  fighting       78.2           7             0
# Tapu Koko   electric     fairy       20.5           7             1
# Tapu Lele    psychic     fairy       18.6           7             1
# Tapu Bulu      grass     fairy       45.5           7             1
# Tapu Fini      water     fairy       21.2           7             1
# Cosmog       psychic       NaN        0.1           7             1
# Cosmoem      psychic       NaN      999.9           7             1
# Solgaleo     psychic     steel      230.0           7             1
# Lunala       psychic     ghost      120.0           7             1
# Nihilego        rock    poison       55.5           7             1
# Buzzwole         bug  fighting      333.6           7             1
# Pheromosa        bug  fighting       25.0           7             1
# Xurkitree   electric       NaN      100.0           7             1
# Celesteela     steel    flying      999.9           7             1
# Kartana        grass     steel        0.1           7             1
# Guzzlord        dark    dragon      888.0           7             1
# Necrozma     psychic       NaN      230.0           7             1
# Magearna       steel     fairy       80.5           7             1
#
# [801 rows x 40 columns]

# %%
pokemon.loc['Bulbasaur']
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                    1
# against_dark                                   1
# against_dragon                                 1
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                   2
# against_flying                                 2
# against_ghost                                  1
# against_grass                               0.25
# against_ground                                 1
# against_ice                                    2
# against_normal                                 1
# against_poison                                 1
# against_psychic                                2
# against_rock                                   1
# against_steel                                  1
# against_water                                0.5
# attack                                        49
# base_egg_steps                              5120
# base_happiness                                70
# base_total                                   318
# capture_rate                                  45
# classfication                       Seed Pokémon
# defense                                       49
# experience_growth                        1059860
# height_m                                     0.7
# hp                                            45
# japanese_name                   Fushigidaneフシギダネ
# percentage_male                             88.1
# pokedex_number                                 1
# sp_attack                                     65
# sp_defense                                    65
# speed                                         45
# type1                                      grass
# type2                                     poison
# weight_kg                                    6.9
# generation                                     1
# is_legendary                                   0
# Name: Bulbasaur, dtype: object

# %%
pokemon.iloc[0]
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                    1
# against_dark                                   1
# against_dragon                                 1
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                   2
# against_flying                                 2
# against_ghost                                  1
# against_grass                               0.25
# against_ground                                 1
# against_ice                                    2
# against_normal                                 1
# against_poison                                 1
# against_psychic                                2
# against_rock                                   1
# against_steel                                  1
# against_water                                0.5
# attack                                        49
# base_egg_steps                              5120
# base_happiness                                70
# base_total                                   318
# capture_rate                                  45
# classfication                       Seed Pokémon
# defense                                       49
# experience_growth                        1059860
# height_m                                     0.7
# hp                                            45
# japanese_name                   Fushigidaneフシギダネ
# percentage_male                             88.1
# pokedex_number                                 1
# sp_attack                                     65
# sp_defense                                    65
# speed                                         45
# type1                                      grass
# type2                                     poison
# weight_kg                                    6.9
# generation                                     1
# is_legendary                                   0
# Name: Bulbasaur, dtype: object

# %% [markdown]
# ## Domande

# %% [markdown]
# - Chi è il pokémon di prima generazione che ha la somma delle statistiche di base massime?

# %%
#map
pokemon['base_total']
# Out:
# name
# Bulbasaur     318
# Ivysaur       405
# Venusaur      625
# Charmander    309
# Charmeleon    405
# Charizard     634
# Squirtle      314
# Wartortle     405
# Blastoise     630
# Caterpie      195
# Metapod       205
# Butterfree    395
# Weedle        195
# Kakuna        205
# Beedrill      495
# Pidgey        251
# Pidgeotto     349
# Pidgeot       579
# Rattata       253
# Raticate      413
# Spearow       262
# Fearow        442
# Ekans         288
# Arbok         448
# Pikachu       320
# Raichu        485
# Sandshrew     300
# Sandslash     450
# Nidoran♀      275
# Nidorina      365
#              ...
# Type: Null    534
# Silvally      570
# Minior        500
# Komala        480
# Turtonator    485
# Togedemaru    435
# Mimikyu       476
# Bruxish       475
# Drampa        485
# Dhelmise      517
# Jangmo-o      300
# Hakamo-o      420
# Kommo-o       600
# Tapu Koko     570
# Tapu Lele     570
# Tapu Bulu     570
# Tapu Fini     570
# Cosmog        200
# Cosmoem       400
# Solgaleo      680
# Lunala        680
# Nihilego      570
# Buzzwole      570
# Pheromosa     570
# Xurkitree     570
# Celesteela    570
# Kartana       570
# Guzzlord      570
# Necrozma      600
# Magearna      600
# Name: base_total, Length: 801, dtype: int64

# %%
#filter
first_gen=pokemon[pokemon['generation']==1]
first_gen.head(9)
# Out:
#                               abilities  against_bug  against_dark  \
# name
# Bulbasaur   ['Overgrow', 'Chlorophyll']         1.00           1.0
# Ivysaur     ['Overgrow', 'Chlorophyll']         1.00           1.0
# Venusaur    ['Overgrow', 'Chlorophyll']         1.00           1.0
# Charmander     ['Blaze', 'Solar Power']         0.50           1.0
# Charmeleon     ['Blaze', 'Solar Power']         0.50           1.0
# Charizard      ['Blaze', 'Solar Power']         0.25           1.0
# Squirtle       ['Torrent', 'Rain Dish']         1.00           1.0
# Wartortle      ['Torrent', 'Rain Dish']         1.00           1.0
# Blastoise      ['Torrent', 'Rain Dish']         1.00           1.0
#
#             against_dragon  against_electric  against_fairy  against_fight  \
# name
# Bulbasaur              1.0               0.5            0.5            0.5
# Ivysaur                1.0               0.5            0.5            0.5
# Venusaur               1.0               0.5            0.5            0.5
# Charmander             1.0               1.0            0.5            1.0
# Charmeleon             1.0               1.0            0.5            1.0
# Charizard              1.0               2.0            0.5            0.5
# Squirtle               1.0               2.0            1.0            1.0
# Wartortle              1.0               2.0            1.0            1.0
# Blastoise              1.0               2.0            1.0            1.0
#
#             against_fire  against_flying  against_ghost  ...  percentage_male  \
# name                                                     ...
# Bulbasaur            2.0             2.0            1.0  ...             88.1
# Ivysaur              2.0             2.0            1.0  ...             88.1
# Venusaur             2.0             2.0            1.0  ...             88.1
# Charmander           0.5             1.0            1.0  ...             88.1
# Charmeleon           0.5             1.0            1.0  ...             88.1
# Charizard            0.5             1.0            1.0  ...             88.1
# Squirtle             0.5             1.0            1.0  ...             88.1
# Wartortle            0.5             1.0            1.0  ...             88.1
# Blastoise            0.5             1.0            1.0  ...             88.1
#
#             pokedex_number  sp_attack  sp_defense  speed  type1   type2  \
# name
# Bulbasaur                1         65          65     45  grass  poison
# Ivysaur                  2         80          80     60  grass  poison
# Venusaur                 3        122         120     80  grass  poison
# Charmander               4         60          50     65   fire     NaN
# Charmeleon               5         80          65     80   fire     NaN
# Charizard                6        159         115    100   fire  flying
# Squirtle                 7         50          64     43  water     NaN
# Wartortle                8         65          80     58  water     NaN
# Blastoise                9        135         115     78  water     NaN
#
#             weight_kg  generation  is_legendary
# name
# Bulbasaur         6.9           1             0
# Ivysaur          13.0           1             0
# Venusaur        100.0           1             0
# Charmander        8.5           1             0
# Charmeleon       19.0           1             0
# Charizard        90.5           1             0
# Squirtle          9.0           1             0
# Wartortle        22.5           1             0
# Blastoise        85.5           1             0
#
# [9 rows x 40 columns]

# %%
#reduce
best_stat = first_gen['base_total'].max()
best_stat
# Out:
# 780

# %%
first_gen[first_gen['base_total'] == best_stat]
# Out:
#                       abilities  against_bug  against_dark  against_dragon  \
# name
# Mewtwo  ['Pressure', 'Unnerve']          2.0           2.0             1.0
#
#         against_electric  against_fairy  against_fight  against_fire  \
# name
# Mewtwo               1.0            1.0            0.5           1.0
#
#         against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# name                                   ...
# Mewtwo             1.0            2.0  ...              NaN             150
#
#         sp_attack  sp_defense  speed    type1  type2  weight_kg  generation  \
# name
# Mewtwo        194         120    140  psychic    NaN      122.0           1
#
#         is_legendary
# name
# Mewtwo             1
#
# [1 rows x 40 columns]

# %% [markdown]
# <b> MFR in action </b>

# %%
#Prodotto fra il triplo dei numeri da 1 a 5 che risulta pari
l = [i for i in range(1,6)]
ltriple = list(map(lambda x: 3*x,l))
evens = list(filter(lambda x: x%2==0,ltriple))

from functools import reduce
product = reduce((lambda x, y: x * y), evens)
product
# Out:
# 72

# %% [markdown]
# - Quanti sono i pokémon di prima generazione che hanno la somma delle statistiche di base maggiori della media?

# %%
strong_pokemon=len(first_gen[first_gen['base_total']>=first_gen['base_total'].mean()])
weak_pokemon=len(pokemon)-strong_pokemon
print("Strong pokemon: " + str(strong_pokemon) + "\n" + "Weak_pokemon: " + str(weak_pokemon) +"\n")
# Out:
# Strong pokemon: 74
# Weak_pokemon: 727

# %% [markdown]
# Visualizziamo l'informazione attraverso un grafico:

# %%
strong_weak=[strong_pokemon,weak_pokemon]
labels=['Strong Pokemon',"Weak Pokemon"]
sw=pd.DataFrame({'': strong_weak},index=labels)
sw.plot.pie(y='', figsize=(5, 5))
plt.show()

# %% [markdown]
# - Qual è il tipo di Pokémon più comune?

# %%
types_abs_freq=(pokemon['type1'].value_counts()+pokemon['type2'].value_counts()).sort_values(ascending=False)
x=types_abs_freq.index
y=types_abs_freq.values
types_abs_freq.plot.bar()
plt.show()

# %% [markdown]
# - Ci sono più pokemon maschi o più pokémon femmina?

# %%
def max_gender(pmale,pfemale):
    gender=""
    if not(pmale) and not(pfemale):
        gender="None"
    elif not(pfemale):
        gender="Male"
    elif not(pmale):
        gender="Female"
    elif pfemale>=pmale:
        gender="Female"
    else:
        gender="Male"
    return gender

# %%
percentage_males = [p if p else None for p in pokemon['percentage_male']]
percentage_females = [(100-p) if p else None for p in pokemon['percentage_male']]

prevalent_genders = []
for i in range(0,len(percentage_females)):
    prevalent_genders.append(max_gender(percentage_males[i],percentage_females[i]))

pd.Series(prevalent_genders).value_counts()
# Out:
# Female    527
# Male      247
# None       27
# dtype: int64

# %% [markdown]
# - Se un pokémon pesa tanto vuol dire che è lento?

# %%
X = first_gen['speed']
Y = first_gen['weight_kg']

plt.scatter(X,Y)
plt.show()

# %%
X.corr(Y,method='pearson')
# Out:
# 0.11706950738197676

# %% [markdown]
# - I pokémon di prima generazione sono forti come quelli di settima?

# %%
first_gen['base_total'].hist(bins=10)
plt.show()

seventh_gen_bstat = pokemon[pokemon['generation']==7]['base_total']
seventh_gen_bstat.hist(bins=10)
plt.show()

# %%
import statsmodels.api as sm

first_gen_sample = first_gen['base_total'].sample(60)
seventh_gen_sample = seventh_gen_bstat.sample(60)

sm.qqplot_2samples(first_gen_sample, seventh_gen_sample, line='45')
plt.show()
